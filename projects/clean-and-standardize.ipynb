# %%
import pandas as pd
import psycopg2
import os
from datetime import date
from configparser import ConfigParser

# %% [markdown]
# ## __About__
# Taking the audited and verified tables we'd created from the prior files, we're now going to further sanitize and standardize (and potentially combine) them to be analysis-ready by the end.

# %%
'''
Copied my config from my 'database-upload' file for ease-of-access.
'''

def config(filename="database.ini", section="postgresql"): # keeping filename for portability, changing later
    parser = ConfigParser() # creating parser
    parser.read(filename) # reading the .ini file
    db = {} # empty dictionary for database

    if parser.has_section(section): # checking if a config section exists
        params = parser.items(section) # "
        for param in params: # reading every setting
            db[param[0]] = param[1] # applying these for later use
        
    else:
        raise Exception("Section {0} not found in the {1} file".format(section, filename))
    
    try:
        conn = psycopg2.connect(**db) # connecting to the db by bypassing the dictionary
        print("Database connected successfully.")
    except:
        print("Database not connected successfully.")
        raise

    return conn

# %%
conn = config(filename=r"C:\Users\Jjoer\GitHub\Pokemon Stocks\database.ini") # connecting to db

df_cards = pd.read_sql_query("SELECT * FROM cards;", conn)
df_prices = pd.read_sql_query("SELECT * FROM prices;", conn)

conn.close() # closing the cursor
# Out:
# Database connected successfully.
# C:\Users\Jjoer\AppData\Local\Temp\ipykernel_13292\1747593040.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_cards = pd.read_sql_query("SELECT * FROM cards;", conn)
# C:\Users\Jjoer\AppData\Local\Temp\ipykernel_13292\1747593040.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_prices = pd.read_sql_query("SELECT * FROM prices;", conn)

# %% [markdown]
# ---
#
# ### *Revisiting old files*
# Having to redo the whole process is redundant, so now we'll turn that into functions to condense the process.

# %% [markdown]
# ##### 'Cards' Table:

# %%
def audit_and_verify_cards_table():
    replacement_values = {"artist": "Unknown Artist", "rarity": "Unknown Rarity"}
    df_replace_artist_and_rarity = df_cards.fillna(value=replacement_values)
    df_cleaned_cards = df_replace_artist_and_rarity.drop(columns=['subtypes'])
    return df_cleaned_cards

df_cards2 = audit_and_verify_cards_table()
df_cards2.head(10)
# Out:
#    card_id        name supertype                    set_name  \
# 0  hgss4-1      Aggron   Pokémon               HS—Triumphant
# 1    xy5-1      Weedle   Pokémon                Primal Clash
# 2    pl1-1    Ampharos   Pokémon                    Platinum
# 3    dp3-1    Ampharos   Pokémon              Secret Wonders
# 4   det1-1   Bulbasaur   Pokémon           Detective Pikachu
# 5    dv1-1     Dratini   Pokémon                Dragon Vault
# 6  mcd19-1    Caterpie   Pokémon  McDonald's Collection 2019
# 7    pl3-1     Absol G   Pokémon             Supreme Victors
# 8   ex12-1  Aerodactyl   Pokémon                Legend Maker
# 9    ex3-1       Absol   Pokémon                      Dragon
#
#                    series card_number printed_total           artist  \
# 0  HeartGold & SoulSilver           1           102  Kagemaru Himeno
# 1                      XY           1           160    Midori Harada
# 2                Platinum           1           127   Atsuko Nishida
# 3         Diamond & Pearl           1           132     Kouki Saitou
# 4              Sun & Moon           1            18         MPC Film
# 5           Black & White           1            20  Masakazu Fukuda
# 6                   Other           1            12            Sekio
# 7                Platinum           1           147  Yusuke Ishikawa
# 8                      EX           1            92  Hajime Kusajima
# 9                      EX           1            97     Naoyo Kimura
#
#            rarity
# 0       Rare Holo
# 1          Common
# 2       Rare Holo
# 3       Rare Holo
# 4          Common
# 5       Rare Holo
# 6  Unknown Rarity
# 7       Rare Holo
# 8       Rare Holo
# 9       Rare Holo

# %%
df_cards2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19818 entries, 0 to 19817
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   card_id        19818 non-null  object
#  1   name           19818 non-null  object
#  2   supertype      19818 non-null  object
#  3   set_name       19818 non-null  object
#  4   series         19818 non-null  object
#  5   card_number    19818 non-null  object
#  6   printed_total  19818 non-null  object
#  7   artist         19818 non-null  object
#  8   rarity         19818 non-null  object
# dtypes: object(9)
# memory usage: 1.4+ MB

# %% [markdown]
# ---
#
# #### 'Prices' Table

# %%
def audit_and_verify_prices_table():
    df_prices['market_price'] = df_prices['market_price'].fillna(df_prices['mid_price']) # filling all missing 'market_price' with mid_price for accuracy's sake
    df_dropped_prices = df_prices.drop(columns=["source", "condition_txt", "raw_json", "created_at"])
    return df_dropped_prices

df_prices2 = audit_and_verify_prices_table()
df_prices2.head(10)
# Out:
#    price_id  card_id          variant  updated_at  market_price  low_price  \
# 0         1  hgss4-1         holofoil  2025-10-16          3.17       3.15
# 1         2  hgss4-1  reverseHolofoil  2025-10-16          4.28       2.00
# 2         3    xy5-1           normal  2025-10-16          0.12       0.01
# 3         4    xy5-1  reverseHolofoil  2025-10-16          0.60       0.19
# 4         5    pl1-1         holofoil  2025-10-16         14.34       5.39
# 5         6    pl1-1  reverseHolofoil  2025-10-16          9.17      10.00
# 6         7    dp3-1         holofoil  2025-10-16         19.65      10.02
# 7         8    dp3-1  reverseHolofoil  2025-10-16         17.26       4.99
# 8         9   det1-1         holofoil  2025-10-16          0.78       0.08
# 9        10    dv1-1         holofoil  2025-10-16          2.38       1.00
#
#    mid_price  high_price
# 0       4.99       19.99
# 1       3.98        9.99
# 2       0.19        1.49
# 3       0.49        1.59
# 4      14.51       35.00
# 5      12.99       13.98
# 6      19.86       39.99
# 7      16.65       18.45
# 8       0.56        5.03
# 9       2.25        6.58

# %%
df_prices2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229157 entries, 0 to 229156
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price_id      229157 non-null  int64
#  1   card_id       229157 non-null  object
#  2   variant       229157 non-null  object
#  3   updated_at    229157 non-null  object
#  4   market_price  229157 non-null  float64
#  5   low_price     229156 non-null  float64
#  6   mid_price     229156 non-null  float64
#  7   high_price    229156 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 14.0+ MB

# %% [markdown]
# ---
#
# ### Inspection and Cleaning
#
# We'll now take to looking at and cleaning up the inconsistencies for the various columns in both of our tables.
#
# #### 'Cards' Table:

# %%
for column in df_cards2:
    unique_values = df_cards2[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
# Out:
# Unique values in column 'card_id': ['hgss4-1' 'xy5-1' 'pl1-1' ... 'me2-62' 'me2-60' 'me2-61']
# Unique values in column 'name': ['Aggron' 'Weedle' 'Ampharos' ... 'Mega Sharpedo ex' 'Mega Diancie ex'
#  'Mega Gengar ex']
# Unique values in column 'supertype': ['Pokémon' 'Trainer' 'Energy']
# Unique values in column 'set_name': ['HS—Triumphant' 'Primal Clash' 'Platinum' 'Secret Wonders'
#  'Detective Pikachu' 'Dragon Vault' "McDonald's Collection 2019"
#  'Supreme Victors' 'Legend Maker' 'Dragon' 'Pokémon Rumble' 'Aquapolis'
#  'Base Set 2' 'HeartGold & SoulSilver' 'Delta Species'
#  'Team Rocket Returns' 'Gym Heroes' 'Fossil' 'Team Up' 'Flashfire'
#  'POP Series 6' 'Steam Siege' 'Crystal Guardians' 'Cosmic Eclipse'
#  'Black & White' 'Hidden Fates' 'Southern Islands' 'Diamond & Pearl'
#  'Burning Shadows' 'POP Series 7' 'Gym Challenge' 'Call of Legends'
#  'Emerald' 'Plasma Blast' "Champion's Path" 'Ancient Origins' 'Sun & Moon'
#  'Holon Phantoms' 'Guardians Rising' 'Team Rocket' 'Phantom Forces'
#  'Legendary Treasures' 'Team Magma vs Team Aqua' 'Next Destinies'
#  'Plasma Freeze' 'Base' 'POP Series 3' 'Great Encounters'
#  'Boundaries Crossed' 'Deoxys' 'Dark Explorers' 'POP Series 5'
#  'Ultra Prism' 'Fates Collide' 'Lost Thunder' 'HS—Unleashed'
#  'DP Black Star Promos' 'Sword & Shield' 'Wizards Black Star Promos'
#  'Vivid Voltage' 'XY' 'POP Series 1' 'Plasma Storm' 'Legendary Collection'
#  'POP Series 9' 'POP Series 4' 'Neo Destiny' 'Neo Revelation' 'Arceus'
#  'Dragon Majesty' 'Unseen Forces' 'Dragons Exalted' 'Legends Awakened'
#  'Shining Legends' 'SWSH Black Star Promos' 'Celestial Storm'
#  'Neo Genesis' "McDonald's Collection 2012" 'Evolutions' 'Majestic Dawn'
#  'Kalos Starter Set' 'Unified Minds' 'Noble Victories'
#  'Nintendo Black Star Promos' 'Forbidden Light' 'Double Crisis'
#  'HGSS Black Star Promos' 'Unbroken Bonds' 'XY Black Star Promos'
#  'Rebel Clash' 'BW Black Star Promos' 'HS—Undaunted' 'BREAKpoint'
#  'BREAKthrough' 'Furious Fists' 'Emerging Powers' 'Expedition Base Set'
#  'Neo Discovery' 'Jungle' 'POP Series 2' 'Mysterious Treasures'
#  'Darkness Ablaze' 'FireRed & LeafGreen' 'Skyridge' 'Stormfront'
#  'Crimson Invasion' 'Generations' 'Roaring Skies' 'Power Keepers'
#  'Hidden Legends' 'Ruby & Sapphire' 'Hidden Fates Shiny Vault'
#  'Rising Rivals' 'Dragon Frontiers' 'Sandstorm' 'SM Black Star Promos'
#  "McDonald's Collection 2011" 'POP Series 8' "McDonald's Collection 2016"
#  '151' 'Shining Fates Shiny Vault' 'Shining Fates' 'Battle Styles'
#  'Chilling Reign' 'Evolving Skies' 'Celebrations'
#  'Celebrations: Classic Collection' "McDonald's Collection 2014"
#  "McDonald's Collection 2015" "McDonald's Collection 2017"
#  "McDonald's Collection 2018" "McDonald's Collection 2021" 'Best of Game'
#  'Fusion Strike' 'Pokémon Futsal Collection' 'EX Trainer Kit Latias'
#  'EX Trainer Kit Latios' 'EX Trainer Kit 2 Plusle'
#  'EX Trainer Kit 2 Minun' 'Brilliant Stars'
#  'Brilliant Stars Trainer Gallery' 'Astral Radiance'
#  'Astral Radiance Trainer Gallery' 'Pokémon GO' 'Lost Origin'
#  'Lost Origin Trainer Gallery' 'Silver Tempest'
#  'Silver Tempest Trainer Gallery' "McDonald's Collection 2022"
#  'Crown Zenith' 'Crown Zenith Galarian Gallery' 'Scarlet & Violet'
#  'Scarlet & Violet Black Star Promos' 'Paldea Evolved'
#  'Scarlet & Violet Energies' 'Obsidian Flames' 'Paradox Rift'
#  'Paldean Fates' 'Temporal Forces' 'Twilight Masquerade' 'Shrouded Fable'
#  'Stellar Crown' 'Surging Sparks' 'Prismatic Evolutions'
#  'Journey Together' 'Destined Rivals' 'Scarlet & Violet Promos'
#  'White Flare' 'Black Bolt' 'Mega Evolution' 'Phantasmal Flames']
# Unique values in column 'series': ['HeartGold & SoulSilver' 'XY' 'Platinum' 'Diamond & Pearl' 'Sun & Moon'
#  'Black & White' 'Other' 'EX' 'E-Card' 'Base' 'Gym' 'POP' 'Sword & Shield'
#  'Neo' 'NP' 'Scarlet & Violet' 'Mega Evolution']
# Unique values in column 'card_number': ['1' 'H1' 'H2' ... 'DP23' 'BW15' '21a']
# Unique values in column 'printed_total': ['102' '160' '127' '132' '18' '20' '12' '147' '92' '97' '16' '130' '123'
#  '113' '109' '62' '181' '106' '17' '114' '100' '236' '68' '95' '101' '73'
#  '98' '149' '110' '145' '82' '119' '99' '116' '107' '108' '156' '124'
#  '214' '56' '202' '53' '185' '146' '135' '105' '64' '70' '115' '307' '168'
#  '111' '39' '40' '131' '34' '25' '211' '192' '90' '122' '162' '165' '75'
#  '189' '112' '144' '83' '94' '248' '72' '163' '198' '203' '9' '264' '5'
#  '10' '172' '30' '78' '196' '195' '15' '159' '215' '193' '197' '182' '91'
#  '167' '142' '191' '150' '86']
# Unique values in column 'artist': ['Kagemaru Himeno' 'Midori Harada' 'Atsuko Nishida' 'Kouki Saitou'
#  'MPC Film' 'Masakazu Fukuda' 'Sekio' 'Yusuke Ishikawa' 'Hajime Kusajima'
#  'Naoyo Kimura' 'Pokemon Rumble' 'Shin-ichi Yoshida' 'Ken Sugimori'
#  'Naoki Saito' 'Sumiyoshi Kizuki' 'Mitsuhiro Arita' 'Kazuyuki Kano'
#  'Kyoko Umemoto' 'Ryo Ueda' 'Daisuke Ito' 'Motofumi Fujiwara' 'kawayoo'
#  'Framestore' 'Shibuzoh.' 'Hisao Nakamura' 'Emi Miwa' 'Satoshi Shirai'
#  'OOYAMA' 'tetsuya koizumi' 'Keiko Fukuyama' 'Nakaoka' 'sui'
#  'PLANETA Mochizuki' 'MAHOU' 'Kanako Eo' 'Yumi' 'Hironobu Yoshida'
#  '5ban Graphics' 'Lee HyunJung' 'Keiji Kinebuchi' 'Shin Nagasawa'
#  'Kyoko Koizumi' 'Yuka Morii' 'kirisAki' 'SATOSHI NAKAI' 'Aya Kusube'
#  'K. Utsunomiya' 'Wataru Kawahara' 'PLANETA Igarashi' 'Eske Yoshinob'
#  'Katsura Tabata' 'Toshinao Aoki' 'Mina Nakai' 'Ayaka Yoshida'
#  'Miki Tanaka' 'Shin-ichi Yoshikawa, CR CG gangs' 'Suwama Chiaki'
#  'Takabon' 'TOKIYA' 'sowsow' 'Akira Komayama' 'Eri Yamaki'
#  'Keiko Moritsugu' 'match' 'K. Hoshiba' 'Mizue' 'Saya Tsuruta' 'kodama'
#  'You Iribi' 'Hideki Ishikawa' 'Tomokazu Komiya' 'Kent Kanetsuna'
#  'Yukiko Baba' 'Megumi Higuchi' 'nagimiso' 'Misa Tsutsui'
#  'Masako Yamashita' 'PLANETA' 'AKIRA EGAWA' 'DemizuPosuka'
#  'Sachiko Adachi' 'Ryuta Fuse' 'Takashi Yamaguchi' 'Yoshinobu Saito'
#  'Megumi Mizutani' 'Hitoshi Ariga' 'Mt. TBT' 'Sanosuke Sakuma'
#  'Shigenori Negishi' 'aky CG Works' 'Nobuyuki Fujimoto' 'Hideaki Hakozaki'
#  'Anesaki Dynamic' 'Reiko Tanoue' 'PLANETA Tsuji' 'Milky Isobe'
#  'Masahiko Ishii' 'Jungo Suzuki' 'Toyste Beach' 'Tomoaki Imakuni'
#  'Kazuaki Aihara' 'CR CG gangs' '0313' 'Shizurow' 'Emi Ando' 'M. Akiyama'
#  'Hiroki Fuchino' 'KEIICHIRO ITO' 'Kimiya Masago' 'Hasuno'
#  'Hiroki Asanuma' 'Keita Komatsuya, CR CG gangs' 'hatachu' 'Noriko Hotta'
#  'Gakuji Nomoto' 'Yuri Umemura' 'Yusuke Ohmura' 'HiRON'
#  'Shin-ichi Yoshikawa' 'otumami' 'T. Honda' 'Asako Ito' 'so-taro'
#  'Atsuko Ujiie' 'Uta' 'Hiroyuki Yamamoto' 'Hikaru Koike' 'Ryota Murayama'
#  'Saki Hayashiro' 'Zu-Ka' 'HYOGONOSUKE' 'Christopher Rush' 'chibi'
#  'Ken Ikuji' 'Takao Unno' 'GAME FREAK inc.' 'K. Hoshiba, CR CG gangs'
#  'NC Empire' 'Kazuma Koda' 'Hiromichi Sugiyama' 'Satoshi Ohta'
#  'Wataru Kawahara/Direc. Shinji Higuchi' 'miki kudo' 'Taira Akitsu'
#  'Tika Matsuno' 'Ryota Saito' 'Makoto Imai' 'ryoma uratsuka'
#  'Hideki Kazama' 'Souichirou Gunjima' '"Big Mama" Tagawa' 'sadaji'
#  'kanahei' 'Yosuke Da Silva' 'Kazuo Yazawa' 'BERUBURI' 'Tomoko Wakai'
#  'Takumi Akabane' 'Emi Yoshida' 'Jumpei Akasaka' 'Kunihiko Yuyama'
#  'Craig Turvey' 'take' 'Kenkichi Toyama' 'Maiko Fujiwara'
#  'Studio Bora Inc.' 'Hasegawa Saki' 'Asuka Iwashita' 'Hizuki Misono'
#  'Hiroaki Ito' 'Aimi Tomita' 'Mikiko Takeda' 'Narumi Sato' 'Kouji Tajima'
#  'Unknown Artist' 'Hiromichi Sugiyama, CR CG gangs'
#  'The Pokémon Company Art Team' 'Tomohiro Kitakaze'
#  'Jungo Suzuki, CR CG gangs' '"Big Mama" Tagawa, CR CG gangs'
#  'Hideyuki Nakajima' 'Etsuya Hattori' '"Big Mama" Tagawa & Benimaru Itoh'
#  'Yuichi Sawayama' 'Shinji Higuchi + Sachiko Eba' 'PLANETA Otani'
#  'Kai Ishikawa' 'Shinji Higuchi + Noriko Takaya'
#  'Katsura Tabata, CR CG gangs' 'Yousuke Hirata, CR CG gangs'
#  'Yasuki Watanabe' 'Ryuta Kusumi, CR CG gangs' 'Imakuni?' 'Shinji Higuchi'
#  'Sachi Matoba' 'Daisuke Iwamoto' '2017 Pikachu Project' 'Pani Kobayashi'
#  'Yusuke Shimada' 'Dr.Ooyama' 'Mana Ibe' 'Mikio Menjo' 'inose yukie'
#  'Kent Kanetsuna/Direc. Shinji Higuchi' 'Ken Sugimori/Yusuke Ohmura'
#  'aoki' '2019 Pikachu Project' 'Sakiko Maeda' 'Junsei Kuninobu'
#  'ConceptLab' 'Q-rais' 'Noriko Uono' 'Nabana Kensaku' 'Tomomi Kaneko'
#  'Misaki Hashimoto' 'Fumie Kittaka' 'Huang Tzu En' 'Avec Yoko'
#  'Yuu Nishida' 'Kinu Nishimura' 'KIYOTAKA OSHIYAMA' 'Atsushi Furusawa'
#  'Mika Pikazo' 'D.A.G Inc.' 'OKACHEKE' 'Teeziro' 'Oswaldo KATO'
#  'Nagomi Nijo' 'AYUMI ODASHIMA' 'En Morikura' 'Yuya Oka' 'Yusuke Kozaki'
#  'MUGENUP' 'K Hoshiba' 'PLANETA Yamashita' 'takuyoa' 'Nisota Niso'
#  'N-DESIGN Inc.' 'Shinji Kanda' 'Rianti Hidayat' 'kurumitsu' 'zig'
#  'GIDORA' 'Scav' 'yuu' 'Shiburingaru' 'DOM' 'Nurikabe' 'Hataya'
#  'ORBITALLINK Inc.' 'saino misaki' 'GOSSAN' 'Ligton' 'akyCG Works'
#  'Jiro Sasumo' 'Shinya Komatsu' 'James Turner' 'Souchirou Gunjima'
#  'PLANETA Hiiragi' 'Amelicart' 'Nelnal' 'Haruko Ichikawa' 'Yano Keiji'
#  'Nobuhiro Imagawa' 'Kurata So' 'nagano' 'Jerky' 'Gemi' 'Haru Akasaka'
#  'SIE NANAHARA' 'kantaro' 'Atsuya Uki' 'Yoriyuki Ikegami' 'hncl'
#  'Po-Suzuki' 'Taiga Kasai' 'Julie Hang' 'REND' 'Masako Tomii' 'Yoshioka'
#  'toriyufu' 'matazo' 'Cona Nitanda' 'OKUBO' 'Natsumi Yoshida'
#  'Tetsu Kayama' 'KYUPIYAMA' 'Tonji Matsuno' 'Bun Toujo' 'Takeshi Nakamura'
#  'Kedamahadaitai Yawarakai' 'rika' 'satoma' 'Kariya' 'Keisin'
#  'Taiga Kayama' 'Oku' 'MINAMINAMI Take' 'nisimono' 'KG-2000' 'Mousho'
#  'aspara' 'Arai Kiriko' 'LINNE' 'Whisker' 'Takumi Wada' 'Benimaru Itoh'
#  'akagi' 'USGMEN' 'Kuroimori' 'hanabushi' 'Dsuke' 'Miranda Branley'
#  'Uninori' 'Rond' 'mingo' 'Saboteri' 'takashi shiraishi' 'Krgc' 'Orca'
#  'cochi8i' 'Makura Tami' 'Katsunori Sato' 'mele' 'Natsumi Miyanose'
#  'Shimaris Yukichi' 'Minato' 'Fujimoto Gold' 'osare' 'toi8' 'GOTO minori'
#  'Mékayu' 'Susumu Maeya' 'Masa' 'Ounishi' 'Tomomi Ozaki' 'Gapao'
#  'Kazumasa Yasukuni' 'danciao' 'Iwamoto05' 'Mugi Hamada'
#  'MARINA Chikazawa' 'Yukihiro Tada' 'Yuriko Akase' 'Ayako Ozaki'
#  'Felicia Chen' 'Minahamu' 'Shinya Mizuno' 'svlt' 'Iori Suzuki' 'Izucch'
#  'mashu' 'Aliya Chen' 'Yoshimi Miyoshi' 'Terada Tera' 'Nakamura Ippan'
#  'Tsuyoshi Nagano' 'YASHIRO Nanaco' 'IKEDA Saki' 'tono' 'Kanami Ogata'
#  'buchi' 'kamonabe' 'Narano' 'Wintr Wandr' 'imoniii' 'Heisuke Kitazawa'
#  'Mori Yuu' 'HICO KIM' 'Natsuko Shoji été' 'Yoko Hishida'
#  'Kamome Shirahama' 'Eri Kamei' 'Tomowaka' 'Apios' 'okayamatakatoshi'
#  'Yuka Tanaka' 'Hoshino KURO' 'Akino Fukuji' 'Nabatame Kazutaka'
#  'Koji Nakata' 'Raita Kazama']
# Unique values in column 'rarity': ['Rare Holo' 'Common' 'Unknown Rarity' 'Rare Holo GX' 'Rare' 'Uncommon'
#  'Rare Holo V' 'Promo' 'Rare Holo EX' 'Rare Ultra' 'Rare Holo VMAX'
#  'Rare Shiny' 'Rare BREAK' 'Rare Prism Star' 'Rare Shining'
#  'Rare Shiny GX' 'Amazing Rare' 'Rare Rainbow' 'Rare Secret' 'Rare Prime'
#  'Rare ACE' 'Rare Holo Star' 'LEGEND' 'Rare Holo LV.X'
#  'Classic Collection' 'Rare Holo VSTAR' 'Trainer Gallery Rare Holo'
#  'Radiant Rare' 'Double Rare' 'Illustration Rare' 'Ultra Rare'
#  'Special Illustration Rare' 'Hyper Rare' 'Shiny Rare' 'Shiny Ultra Rare'
#  'ACE SPEC Rare' 'Black White Rare' 'Mega Hyper Rare']

# %% [markdown]
# For our 'cards' table, there are no changes that we need to make.

# %% [markdown]
# ---
#
# #### 'Prices' Table:

# %%
for column in df_prices2:
    unique_values = df_prices2[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
# Out:
# Unique values in column 'price_id': [     1      2      3 ... 262307 262308 262309]
# Unique values in column 'card_id': ['hgss4-1' 'xy5-1' 'pl1-1' ... 'me2-130' 'me2-128' 'me2-126']
# Unique values in column 'variant': ['holofoil' 'reverseHolofoil' 'normal' '1stEditionHolofoil'
#  'unlimitedHolofoil' '1stEdition' 'unlimited']
# Unique values in column 'updated_at': [datetime.date(2025, 10, 16) datetime.date(2025, 9, 19)
#  datetime.date(2025, 9, 17) datetime.date(2025, 9, 25)
#  datetime.date(2025, 10, 14) datetime.date(2025, 7, 23)
#  datetime.date(2025, 8, 15) datetime.date(2025, 5, 20)
#  datetime.date(2024, 1, 15) datetime.date(2025, 10, 12)
#  datetime.date(2025, 4, 28) datetime.date(2025, 8, 10)
#  datetime.date(2025, 8, 9) datetime.date(2025, 6, 20)
#  datetime.date(2025, 8, 3) datetime.date(2025, 9, 30)
#  datetime.date(2025, 10, 1) datetime.date(2025, 5, 12)
#  datetime.date(2025, 8, 13) datetime.date(2025, 8, 31)
#  datetime.date(2025, 8, 4) datetime.date(2025, 7, 3)
#  datetime.date(2025, 9, 16) datetime.date(2025, 7, 12)
#  datetime.date(2025, 10, 13) datetime.date(2025, 9, 26)
#  datetime.date(2025, 10, 6) datetime.date(2025, 7, 18)
#  datetime.date(2023, 3, 1) datetime.date(2024, 2, 4)
#  datetime.date(2025, 8, 29) datetime.date(2025, 6, 24)
#  datetime.date(2025, 8, 8) datetime.date(2024, 6, 5)
#  datetime.date(2025, 10, 21) datetime.date(2025, 10, 19)
#  datetime.date(2025, 10, 18) datetime.date(2025, 10, 20)
#  datetime.date(2025, 10, 29) datetime.date(2025, 10, 23)
#  datetime.date(2025, 10, 26) datetime.date(2025, 10, 25)
#  datetime.date(2025, 10, 28) datetime.date(2025, 11, 10)
#  datetime.date(2025, 11, 9) datetime.date(2025, 10, 30)
#  datetime.date(2025, 11, 6) datetime.date(2025, 11, 4)
#  datetime.date(2025, 11, 7) datetime.date(2025, 11, 2)
#  datetime.date(2025, 11, 3) datetime.date(2025, 11, 14)
#  datetime.date(2025, 11, 13) datetime.date(2025, 11, 12)
#  datetime.date(2025, 11, 11) datetime.date(2025, 11, 19)
#  datetime.date(2025, 11, 16) datetime.date(2025, 11, 17)
#  datetime.date(2025, 11, 15) datetime.date(2025, 12, 5)
#  datetime.date(2025, 12, 4) datetime.date(2025, 11, 21)
#  datetime.date(2025, 11, 28) datetime.date(2025, 12, 2)
#  datetime.date(2025, 11, 25)]
# Unique values in column 'market_price': [3.1700e+00 4.2800e+00 1.2000e-01 ... 2.2544e+02 7.8920e+01 7.9720e+01]
# Unique values in column 'low_price': [3.1500e+00 2.0000e+00 1.0000e-02 ... 6.3890e+01 5.6399e+02 3.7190e+01]
# Unique values in column 'mid_price': [4.9900e+00 3.9800e+00 1.9000e-01 ... 2.0316e+02 8.4320e+01 1.6600e+02]
# Unique values in column 'high_price': [ 19.99   9.99   1.49 ...  80.14  88.99 271.3 ]

# %% [markdown]
# For our 'prices' table, we'll need to not only change 'updated_at' to the date datatype, but we'll also reinforce the float datatype in the prices columns and change the names of the various 'variant' elements to be more readable.

# %%
columns_to_float = ["market_price", "low_price", "mid_price", "high_price"] # columns we want to reinforce as 'float64'
df_prices2[columns_to_float] = df_prices2[columns_to_float].astype('float64')
df_prices2['updated_at'] = pd.to_datetime(df_prices2['updated_at'])

df_prices2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229157 entries, 0 to 229156
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price_id      229157 non-null  int64
#  1   card_id       229157 non-null  object
#  2   variant       229157 non-null  object
#  3   updated_at    229157 non-null  datetime64[ns]
#  4   market_price  229157 non-null  float64
#  5   low_price     229156 non-null  float64
#  6   mid_price     229156 non-null  float64
#  7   high_price    229156 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 14.0+ MB

# %% [markdown]
# Changing all the variants that we encountered for readability.

# %%
df_prices2["variant"] = df_prices2["variant"].replace({ # replacing en masse for readability
    "reverseHolofoil": "Reverse Holofoil",
    "normal": "Normal",
    "holofoil": "Holofoil",
    "1stEdition": "1st. Edition",
    "unlimited": "Unlimited",
    "1stEditionHolofoil": "1st. Edition Holofoil",
    "unlimitedHolofoil": "Unlimited Holofoil"})

df_prices2.head(10)
# Out:
#    price_id  card_id           variant updated_at  market_price  low_price  \
# 0         1  hgss4-1          Holofoil 2025-10-16          3.17       3.15
# 1         2  hgss4-1  Reverse Holofoil 2025-10-16          4.28       2.00
# 2         3    xy5-1            Normal 2025-10-16          0.12       0.01
# 3         4    xy5-1  Reverse Holofoil 2025-10-16          0.60       0.19
# 4         5    pl1-1          Holofoil 2025-10-16         14.34       5.39
# 5         6    pl1-1  Reverse Holofoil 2025-10-16          9.17      10.00
# 6         7    dp3-1          Holofoil 2025-10-16         19.65      10.02
# 7         8    dp3-1  Reverse Holofoil 2025-10-16         17.26       4.99
# 8         9   det1-1          Holofoil 2025-10-16          0.78       0.08
# 9        10    dv1-1          Holofoil 2025-10-16          2.38       1.00
#
#    mid_price  high_price
# 0       4.99       19.99
# 1       3.98        9.99
# 2       0.19        1.49
# 3       0.49        1.59
# 4      14.51       35.00
# 5      12.99       13.98
# 6      19.86       39.99
# 7      16.65       18.45
# 8       0.56        5.03
# 9       2.25        6.58

# %% [markdown]
# ---
#
# ### Checking the integrity between both tables
#
# Finally, we need to make sure that every element between both tables has a match and there are no 'forgotten' or 'corrupt' cards/prices.

# %%
orphaned_prices = df_prices2[~df_prices2["card_id"].isin(df_cards2['card_id'])] # using the ~ (not in) modifier to print out what's not shared between the two datasets

print(orphaned_prices)
# Out:
# Empty DataFrame
# Columns: [price_id, card_id, variant, updated_at, market_price, low_price, mid_price, high_price]
# Index: []

# %% [markdown]
# With that empty dataset, we're now able to see that we have no further issues needed to resolve and we can merge the rows proper and get to working on our analysis, having finally completed our pipeline.
#
# ---
#
# ### Merging tables to create one
# And now it's time to merge tables and began our analysis proper.

# %%
df_full = df_prices2.merge(df_cards2, on="card_id", how="left") # merging left on the card id to prevent extra rows from being create if merging right

df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229157 entries, 0 to 229156
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   price_id       229157 non-null  int64
#  1   card_id        229157 non-null  object
#  2   variant        229157 non-null  object
#  3   updated_at     229157 non-null  datetime64[ns]
#  4   market_price   229157 non-null  float64
#  5   low_price      229156 non-null  float64
#  6   mid_price      229156 non-null  float64
#  7   high_price     229156 non-null  float64
#  8   name           229157 non-null  object
#  9   supertype      229157 non-null  object
#  10  set_name       229157 non-null  object
#  11  series         229157 non-null  object
#  12  card_number    229157 non-null  object
#  13  printed_total  229157 non-null  object
#  14  artist         229157 non-null  object
#  15  rarity         229157 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(10)
# memory usage: 28.0+ MB

# %% [markdown]
# ---
#
# ### Reordering Columns
#
# Finally, we'll reorder columns for readability and visibility and then wrap up in an Excel spreadsheet.

# %%
new_order = ["price_id", "card_id", "name", "variant", "rarity", "supertype", "series", "set_name", "card_number", "printed_total", "artist", "market_price", "low_price", "mid_price", "high_price", "updated_at"]
df_complete = df_full.loc[:, new_order] # re-ordering for readability

df_complete.head(10)
# Out:
#    price_id  card_id       name           variant     rarity supertype  \
# 0         1  hgss4-1     Aggron          Holofoil  Rare Holo   Pokémon
# 1         2  hgss4-1     Aggron  Reverse Holofoil  Rare Holo   Pokémon
# 2         3    xy5-1     Weedle            Normal     Common   Pokémon
# 3         4    xy5-1     Weedle  Reverse Holofoil     Common   Pokémon
# 4         5    pl1-1   Ampharos          Holofoil  Rare Holo   Pokémon
# 5         6    pl1-1   Ampharos  Reverse Holofoil  Rare Holo   Pokémon
# 6         7    dp3-1   Ampharos          Holofoil  Rare Holo   Pokémon
# 7         8    dp3-1   Ampharos  Reverse Holofoil  Rare Holo   Pokémon
# 8         9   det1-1  Bulbasaur          Holofoil     Common   Pokémon
# 9        10    dv1-1    Dratini          Holofoil  Rare Holo   Pokémon
#
#                    series           set_name card_number printed_total  \
# 0  HeartGold & SoulSilver      HS—Triumphant           1           102
# 1  HeartGold & SoulSilver      HS—Triumphant           1           102
# 2                      XY       Primal Clash           1           160
# 3                      XY       Primal Clash           1           160
# 4                Platinum           Platinum           1           127
# 5                Platinum           Platinum           1           127
# 6         Diamond & Pearl     Secret Wonders           1           132
# 7         Diamond & Pearl     Secret Wonders           1           132
# 8              Sun & Moon  Detective Pikachu           1            18
# 9           Black & White       Dragon Vault           1            20
#
#             artist  market_price  low_price  mid_price  high_price updated_at
# 0  Kagemaru Himeno          3.17       3.15       4.99       19.99 2025-10-16
# 1  Kagemaru Himeno          4.28       2.00       3.98        9.99 2025-10-16
# 2    Midori Harada          0.12       0.01       0.19        1.49 2025-10-16
# 3    Midori Harada          0.60       0.19       0.49        1.59 2025-10-16
# 4   Atsuko Nishida         14.34       5.39      14.51       35.00 2025-10-16
# 5   Atsuko Nishida          9.17      10.00      12.99       13.98 2025-10-16
# 6     Kouki Saitou         19.65      10.02      19.86       39.99 2025-10-16
# 7     Kouki Saitou         17.26       4.99      16.65       18.45 2025-10-16
# 8         MPC Film          0.78       0.08       0.56        5.03 2025-10-16
# 9  Masakazu Fukuda          2.38       1.00       2.25        6.58 2025-10-16

# %% [markdown]
# ---
#
# ### Exporting
#
# The title says it all: we'll end with exporting the file to a .csv.

# %%
folder_path = "../data/processed"
today = date.today().strftime("%Y-%m-%d")
filename = f"analytics_{today}.csv"

os.makedirs(folder_path, exist_ok=True)

final_path = f"{folder_path}/{filename}"

df_complete.to_csv(final_path, index=False)

# %% [markdown]
# ---
